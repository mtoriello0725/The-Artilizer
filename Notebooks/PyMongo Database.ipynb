# %% [markdown]
# # Using Mlab Pymongo Database:

# %% [markdown]
# #### Test notebook for mongodb connection

# %%
# imports:
import pymongo
from config import *

# %%
conn = f"mongodb://{dbuser}:{dbpassword}@ds035014.mlab.com:35014/spotify_artists"
client = pymongo.MongoClient(conn)
db = client.spotify_artists

# %%
artistCollection = db["Foster_The_People"]

# %%
objList = []
for i in artistCollection.find({"key": 6}, {"_id": False,"artist_name":True, "track_name":True}):
    objList.append(i)

# %%
objList
# Out:
# [{'artist_name': 'Foster_The_People', 'track_name': 'Pay the Man'},
#  {'artist_name': 'Foster_The_People', 'track_name': 'Sit Next to Me'},
#  {'artist_name': 'Foster_The_People', 'track_name': 'SHC'},
#  {'artist_name': 'Foster_The_People', 'track_name': 'III'},
#  {'artist_name': 'Foster_The_People',
#   'track_name': 'Are You What You Want to Be?'},
#  {'artist_name': 'Foster_The_People', 'track_name': 'Nevermind'}]

# %%
attrDict = {
    "_id": False,
    "acousticness": True,
    "danceability": True,
    "energy": True,
    "instrumentalness": True,
    "liveness": True,
    "speechiness": True,
    "valence": True
    }

# %%
newList = []
for i in artistCollection.find({},attrDict):
    newList.append(i)

# %%
newList
# Out:
# [{'danceability': 0.688,
#   'energy': 0.769,
#   'speechiness': 0.0376,
#   'acousticness': 0.00148,
#   'instrumentalness': 1.08e-05,
#   'liveness': 0.262,
#   'valence': 0.505},
#  {'danceability': 0.558,
#   'energy': 0.813,
#   'speechiness': 0.0462,
#   'acousticness': 0.0036,
#   'instrumentalness': 0.00358,
#   'liveness': 0.179,
#   'valence': 0.616},
#  {'danceability': 0.638,
#   'energy': 0.738,
#   'speechiness': 0.0292,
#   'acousticness': 0.117,
#   'instrumentalness': 0.000384,
#   'liveness': 0.689,
#   'valence': 0.657},
#  {'danceability': 0.5,
#   'energy': 0.859,
#   'speechiness': 0.0506,
#   'acousticness': 0.00126,
#   'instrumentalness': 0.00279,
#   'liveness': 0.329,
#   'valence': 0.269},
#  {'danceability': 0.705,
#   'energy': 0.887,
#   'speechiness': 0.0318,
#   'acousticness': 0.0323,
#   'instrumentalness': 0.000578,
#   'liveness': 0.227,
#   'valence': 0.873},
#  {'danceability': 0.472,
#   'energy': 0.716,
#   'speechiness': 0.0502,
# ...
